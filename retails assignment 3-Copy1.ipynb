# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
# %pwd
# Out:
# 'C:\\Users\\Vandana Shukla\\Downloads\\ASGNM\\retail c'

# %%
cust
cust=pd.read_csv('Customer.csv')
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
cust.isna().sum()
# Out:
# customer_Id    0
# DOB            0
# Gender         2
# city_code      2
# dtype: int64

# %%
prod=pd.read_csv('prod_cat_info.csv',sep=',')
prod
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %%
prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   prod_cat_code      23 non-null     int64
#  1   prod_cat           23 non-null     object
#  2   prod_sub_cat_code  23 non-null     int64
#  3   prod_subcat        23 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 864.0+ bytes

# %%
prod.isna().sum()
# Out:
# prod_cat_code        0
# prod_cat             0
# prod_sub_cat_code    0
# prod_subcat          0
# dtype: int64

# %%
transt=pd.read_csv(r'C:\Users\Vandana Shukla\Downloads\ASGNM\retail c\Transactions.csv ')
transt
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
transt.isna().sum()
# Out:
# transaction_id      0
# cust_id             0
# tran_date           0
# prod_subcat_code    0
# prod_cat_code       0
# Qty                 0
# Rate                0
# Tax                 0
# total_amt           0
# Store_type          0
# dtype: int64

# %%
import os

# %%
prod.count()
# Out:
# prod_cat_code        23
# prod_cat             23
# prod_sub_cat_code    23
# prod_subcat          23
# dtype: int64

# %%
prod.describe()
# Out:
#        prod_cat_code  prod_sub_cat_code
# count      23.000000          23.000000
# mean        3.739130           6.130435
# std         1.711389           3.805550
# min         1.000000           1.000000
# 25%         2.500000           3.000000
# 50%         4.000000           5.000000
# 75%         5.000000          10.000000
# max         6.000000          12.000000

# %%
prod.describe(include='all')
# Out:
#         prod_cat_code prod_cat  prod_sub_cat_code prod_subcat
# count       23.000000       23          23.000000          23
# unique            NaN        6                NaN          18
# top               NaN    Books                NaN        Mens
# freq              NaN        6                NaN           3
# mean         3.739130      NaN           6.130435         NaN
# std          1.711389      NaN           3.805550         NaN
# min          1.000000      NaN           1.000000         NaN
# 25%          2.500000      NaN           3.000000         NaN
# 50%          4.000000      NaN           5.000000         NaN
# 75%          5.000000      NaN          10.000000         NaN
# max          6.000000      NaN          12.000000         NaN

# %%
cust
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
cust.sort_index()
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
cust.sort_values
# Out:
# <bound method DataFrame.sort_values of       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]>

# %%
sheet=pd.merge(cust, prod,left_on='customer_Id',right_on='prod_cat_code',how='outer')
sheet
# Out:
#       customer_Id         DOB Gender  city_code  prod_cat_code  \
# 0        268408.0  02-01-1970      M        4.0            NaN
# 1        269696.0  07-01-1970      F        8.0            NaN
# 2        268159.0  08-01-1970      F        8.0            NaN
# 3        270181.0  10-01-1970      F        2.0            NaN
# 4        268073.0  11-01-1970      M        1.0            NaN
# ...           ...         ...    ...        ...            ...
# 5665          NaN         NaN    NaN        NaN            5.0
# 5666          NaN         NaN    NaN        NaN            6.0
# 5667          NaN         NaN    NaN        NaN            6.0
# 5668          NaN         NaN    NaN        NaN            6.0
# 5669          NaN         NaN    NaN        NaN            6.0
#
#               prod_cat  prod_sub_cat_code prod_subcat
# 0                  NaN                NaN         NaN
# 1                  NaN                NaN         NaN
# ...

# %%
sheet.isna().sum()
# Out:
# customer_Id            23
# DOB                    23
# Gender                 25
# city_code              25
# prod_cat_code        5647
# prod_cat             5647
# prod_sub_cat_code    5647
# prod_subcat          5647
# dtype: int64

# %%
sheet.sort_index()
# Out:
#       customer_Id         DOB Gender  city_code  prod_cat_code  \
# 0        268408.0  02-01-1970      M        4.0            NaN
# 1        269696.0  07-01-1970      F        8.0            NaN
# 2        268159.0  08-01-1970      F        8.0            NaN
# 3        270181.0  10-01-1970      F        2.0            NaN
# 4        268073.0  11-01-1970      M        1.0            NaN
# ...           ...         ...    ...        ...            ...
# 5665          NaN         NaN    NaN        NaN            5.0
# 5666          NaN         NaN    NaN        NaN            6.0
# 5667          NaN         NaN    NaN        NaN            6.0
# 5668          NaN         NaN    NaN        NaN            6.0
# 5669          NaN         NaN    NaN        NaN            6.0
#
#               prod_cat  prod_sub_cat_code prod_subcat
# 0                  NaN                NaN         NaN
# 1                  NaN                NaN         NaN
# ...

# %%
transt
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
transt.isna().sum()
# Out:
# transaction_id      0
# cust_id             0
# tran_date           0
# prod_subcat_code    0
# prod_cat_code       0
# Qty                 0
# Rate                0
# Tax                 0
# total_amt           0
# Store_type          0
# dtype: int64

# %%
full=pd.merge(sheet, transt, left_on='customer_Id',right_on='transaction_id',how='outer',indicator=True)
full
# Out:
#        customer_Id         DOB Gender  city_code  prod_cat_code_x prod_cat  \
# 0         268408.0  02-01-1970      M        4.0              NaN      NaN
# 1         269696.0  07-01-1970      F        8.0              NaN      NaN
# 2         268159.0  08-01-1970      F        8.0              NaN      NaN
# 3         270181.0  10-01-1970      F        2.0              NaN      NaN
# 4         268073.0  11-01-1970      M        1.0              NaN      NaN
# ...            ...         ...    ...        ...              ...      ...
# 28718          NaN         NaN    NaN        NaN              NaN      NaN
# 28719          NaN         NaN    NaN        NaN              NaN      NaN
# 28720          NaN         NaN    NaN        NaN              NaN      NaN
# 28721          NaN         NaN    NaN        NaN              NaN      NaN
# 28722          NaN         NaN    NaN        NaN              NaN      NaN
#
# ...

# %%
full.columns
# Out:
# Index(['customer_Id', 'DOB', 'Gender', 'city_code', 'prod_cat_code_x',
#        'prod_cat', 'prod_sub_cat_code', 'prod_subcat', 'transaction_id',
#        'cust_id', 'tran_date', 'prod_subcat_code', 'prod_cat_code_y', 'Qty',
#        'Rate', 'Tax', 'total_amt', 'Store_type', '_merge'],
#       dtype='object')

# %%
full.dtypes
# Out:
# customer_Id           float64
# DOB                    object
# Gender                 object
# city_code             float64
# prod_cat_code_x       float64
# prod_cat               object
# prod_sub_cat_code     float64
# prod_subcat            object
# transaction_id        float64
# cust_id               float64
# tran_date              object
# prod_subcat_code      float64
# prod_cat_code_y       float64
# Qty                   float64
# Rate                  float64
# Tax                   float64
# total_amt             float64
# Store_type             object
# _merge               category
# dtype: object

# %%
full.head(10)
# Out:
#    customer_Id         DOB Gender  city_code  prod_cat_code_x prod_cat  \
# 0     268408.0  02-01-1970      M        4.0              NaN      NaN
# 1     269696.0  07-01-1970      F        8.0              NaN      NaN
# 2     268159.0  08-01-1970      F        8.0              NaN      NaN
# 3     270181.0  10-01-1970      F        2.0              NaN      NaN
# 4     268073.0  11-01-1970      M        1.0              NaN      NaN
# 5     273216.0  15-01-1970      F        5.0              NaN      NaN
# 6     266929.0  15-01-1970      M        8.0              NaN      NaN
# 7     275152.0  16-01-1970      M        4.0              NaN      NaN
# 8     275034.0  18-01-1970      F        4.0              NaN      NaN
# 9     273966.0  21-01-1970      M        8.0              NaN      NaN
#
#    prod_sub_cat_code prod_subcat  transaction_id  cust_id tran_date  \
# 0                NaN         NaN             NaN      NaN       NaN
# ...

# %%
full.tail(10)
# Out:
#        customer_Id  DOB Gender  city_code  prod_cat_code_x prod_cat  \
# 28713          NaN  NaN    NaN        NaN              NaN      NaN
# 28714          NaN  NaN    NaN        NaN              NaN      NaN
# 28715          NaN  NaN    NaN        NaN              NaN      NaN
# 28716          NaN  NaN    NaN        NaN              NaN      NaN
# 28717          NaN  NaN    NaN        NaN              NaN      NaN
# 28718          NaN  NaN    NaN        NaN              NaN      NaN
# 28719          NaN  NaN    NaN        NaN              NaN      NaN
# 28720          NaN  NaN    NaN        NaN              NaN      NaN
# 28721          NaN  NaN    NaN        NaN              NaN      NaN
# 28722          NaN  NaN    NaN        NaN              NaN      NaN
#
#        prod_sub_cat_code prod_subcat  transaction_id   cust_id   tran_date  \
# 28713                NaN         NaN    4.958404e+10  273010.0  25-01-2011
# ...

# %%
full.describe()
# Out:
#          customer_Id    city_code  prod_cat_code_x  prod_sub_cat_code  \
# count    5647.000000  5645.000000        23.000000          23.000000
# mean   271037.281034     5.472631         3.739130           6.130435
# std      2451.261711     2.859918         1.711389           3.805550
# min    266783.000000     1.000000         1.000000           1.000000
# 25%    268912.000000     3.000000         2.500000           3.000000
# 50%    271028.000000     5.000000         4.000000           5.000000
# 75%    273180.000000     8.000000         5.000000          10.000000
# max    275265.000000    10.000000         6.000000          12.000000
#
#        transaction_id        cust_id  prod_subcat_code  prod_cat_code_y  \
# count    2.305300e+04   23053.000000      23053.000000     23053.000000
# mean     5.007348e+10  271021.746497          6.149091         3.763632
# std      2.898194e+10    2431.692059          3.726372         1.677016
# ...

# %%
full.city_code.value_counts()
# Out:
# 3.0     595
# 5.0     586
# 4.0     582
# 7.0     575
# 2.0     564
# 8.0     562
# 10.0    558
# 1.0     551
# 9.0     546
# 6.0     526
# Name: city_code, dtype: int64

# %%
full.city_code[full.city_code =='$$$']=np.nan
full
# Out:
# <ipython-input-73-a7adaa0ae0c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full.city_code[full.city_code =='$$$']=np.nan
#        customer_Id         DOB Gender  city_code  prod_cat_code_x prod_cat  \
# 0         268408.0  02-01-1970      M        4.0              NaN      NaN
# 1         269696.0  07-01-1970      F        8.0              NaN      NaN
# 2         268159.0  08-01-1970      F        8.0              NaN      NaN
# 3         270181.0  10-01-1970      F        2.0              NaN      NaN
# 4         268073.0  11-01-1970      M        1.0              NaN      NaN
# ...            ...         ...    ...        ...              ...      ...
# 28718          NaN         NaN    NaN        NaN              NaN      NaN
# ...

# %%
full.city_code.value_counts()
# Out:
# 3.0     595
# 5.0     586
# 4.0     582
# 7.0     575
# 2.0     564
# 8.0     562
# 10.0    558
# 1.0     551
# 9.0     546
# 6.0     526
# Name: city_code, dtype: int64

# %%
full.city_code.isna().sum()
# Out:
# 23078

# %%
 def mis_place(x):
    x[x=="$"]=np.nan
    return x

# %%
full1=full.copy()

# %%
full2=full1.apply(mis_place)
full2
# Out:
#        customer_Id         DOB Gender  city_code  prod_cat_code_x prod_cat  \
# 0         268408.0  02-01-1970      M        4.0              NaN      NaN
# 1         269696.0  07-01-1970      F        8.0              NaN      NaN
# 2         268159.0  08-01-1970      F        8.0              NaN      NaN
# 3         270181.0  10-01-1970      F        2.0              NaN      NaN
# 4         268073.0  11-01-1970      M        1.0              NaN      NaN
# ...            ...         ...    ...        ...              ...      ...
# 28718          NaN         NaN    NaN        NaN              NaN      NaN
# 28719          NaN         NaN    NaN        NaN              NaN      NaN
# 28720          NaN         NaN    NaN        NaN              NaN      NaN
# 28721          NaN         NaN    NaN        NaN              NaN      NaN
# 28722          NaN         NaN    NaN        NaN              NaN      NaN
#
# ...

# %%
full2.isna().sum()
# Out:
# customer_Id          23076
# DOB                  23076
# Gender               23078
# city_code            23078
# prod_cat_code_x      28700
# prod_cat             28700
# prod_sub_cat_code    28700
# prod_subcat          28700
# transaction_id        5670
# cust_id               5670
# tran_date             5670
# prod_subcat_code      5670
# prod_cat_code_y       5670
# Qty                   5670
# Rate                  5670
# Tax                   5670
# total_amt             5670
# Store_type            5670
# _merge                   0
# dtype: int64

# %%
full2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28723 entries, 0 to 28722
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_Id        5647 non-null   float64
#  1   DOB                5647 non-null   object
#  2   Gender             5645 non-null   object
#  3   city_code          5645 non-null   float64
#  4   prod_cat_code_x    23 non-null     float64
#  5   prod_cat           23 non-null     object
#  6   prod_sub_cat_code  23 non-null     float64
#  7   prod_subcat        23 non-null     object
#  8   transaction_id     23053 non-null  float64
#  9   cust_id            23053 non-null  float64
#  10  tran_date          23053 non-null  object
#  11  prod_subcat_code   23053 non-null  float64
#  12  prod_cat_code_y    23053 non-null  float64
#  13  Qty                23053 non-null  float64
#  14  Rate               23053 non-null  float64
# ...

# %%
full
# Out:
#        customer_Id         DOB Gender  city_code  prod_cat_code_x prod_cat  \
# 0         268408.0  02-01-1970      M        4.0              NaN      NaN
# 1         269696.0  07-01-1970      F        8.0              NaN      NaN
# 2         268159.0  08-01-1970      F        8.0              NaN      NaN
# 3         270181.0  10-01-1970      F        2.0              NaN      NaN
# 4         268073.0  11-01-1970      M        1.0              NaN      NaN
# ...            ...         ...    ...        ...              ...      ...
# 28718          NaN         NaN    NaN        NaN              NaN      NaN
# 28719          NaN         NaN    NaN        NaN              NaN      NaN
# 28720          NaN         NaN    NaN        NaN              NaN      NaN
# 28721          NaN         NaN    NaN        NaN              NaN      NaN
# 28722          NaN         NaN    NaN        NaN              NaN      NaN
#
# ...

# %%
full.groupby
# Out:
# <bound method DataFrame.groupby of        customer_Id         DOB Gender  city_code  prod_cat_code_x prod_cat  \
# 0         268408.0  02-01-1970      M        4.0              NaN      NaN
# 1         269696.0  07-01-1970      F        8.0              NaN      NaN
# 2         268159.0  08-01-1970      F        8.0              NaN      NaN
# 3         270181.0  10-01-1970      F        2.0              NaN      NaN
# 4         268073.0  11-01-1970      M        1.0              NaN      NaN
# ...            ...         ...    ...        ...              ...      ...
# 28718          NaN         NaN    NaN        NaN              NaN      NaN
# 28719          NaN         NaN    NaN        NaN              NaN      NaN
# 28720          NaN         NaN    NaN        NaN              NaN      NaN
# 28721          NaN         NaN    NaN        NaN              NaN      NaN
# 28722          NaN         NaN    NaN        NaN              NaN      NaN
#
# ...

# %%
full.groupby('Gender').agg(np.mean)
# Out:
#           customer_Id  city_code  prod_cat_code_x  prod_sub_cat_code  \
# Gender
# F       271023.310934   5.507631              NaN                NaN
# M       271051.703320   5.440332              NaN                NaN
#
#         transaction_id  cust_id  prod_subcat_code  prod_cat_code_y  Qty  Rate  \
# Gender
# F                  NaN      NaN               NaN              NaN  NaN   NaN
# M                  NaN      NaN               NaN              NaN  NaN   NaN
#
#         Tax  total_amt
# Gender
# F       NaN        NaN
# M       NaN        NaN

# %%
full.fillna(full.mean(),inplace=True)
full
# Out:
#          customer_Id         DOB Gender  city_code  prod_cat_code_x prod_cat  \
# 0      268408.000000  02-01-1970      M   4.000000          3.73913      NaN
# 1      269696.000000  07-01-1970      F   8.000000          3.73913      NaN
# 2      268159.000000  08-01-1970      F   8.000000          3.73913      NaN
# 3      270181.000000  10-01-1970      F   2.000000          3.73913      NaN
# 4      268073.000000  11-01-1970      M   1.000000          3.73913      NaN
# ...              ...         ...    ...        ...              ...      ...
# 28718  271037.281034         NaN    NaN   5.472631          3.73913      NaN
# 28719  271037.281034         NaN    NaN   5.472631          3.73913      NaN
# 28720  271037.281034         NaN    NaN   5.472631          3.73913      NaN
# 28721  271037.281034         NaN    NaN   5.472631          3.73913      NaN
# 28722  271037.281034         NaN    NaN   5.472631          3.73913      NaN
#
# ...

# %%
full.isna().sum()
# Out:
# customer_Id              0
# DOB                  23076
# Gender               23078
# city_code                0
# prod_cat_code_x          0
# prod_cat             28700
# prod_sub_cat_code        0
# prod_subcat          28700
# transaction_id           0
# cust_id                  0
# tran_date             5670
# prod_subcat_code         0
# prod_cat_code_y          0
# Qty                      0
# Rate                     0
# Tax                      0
# total_amt                0
# Store_type            5670
# _merge                   0
# dtype: int64

# %%
full.count()
# Out:
# customer_Id          28723
# DOB                   5647
# Gender                5645
# city_code            28723
# prod_cat_code_x      28723
# prod_cat                23
# prod_sub_cat_code    28723
# prod_subcat             23
# transaction_id       28723
# cust_id              28723
# tran_date            23053
# prod_subcat_code     28723
# prod_cat_code_y      28723
# Qty                  28723
# Rate                 28723
# Tax                  28723
# total_amt            28723
# Store_type           23053
# _merge               28723
# dtype: int64

# %%
full.dtypes
# Out:
# customer_Id           float64
# DOB                    object
# Gender                 object
# city_code             float64
# prod_cat_code_x       float64
# prod_cat               object
# prod_sub_cat_code     float64
# prod_subcat            object
# transaction_id        float64
# cust_id               float64
# tran_date              object
# prod_subcat_code      float64
# prod_cat_code_y       float64
# Qty                   float64
# Rate                  float64
# Tax                   float64
# total_amt             float64
# Store_type             object
# _merge               category
# dtype: object

# %%
full.count()
# Out:
# customer_Id          28723
# DOB                   5647
# Gender                5645
# city_code            28723
# prod_cat_code_x      28723
# prod_cat                23
# prod_sub_cat_code    28723
# prod_subcat             23
# transaction_id       28723
# cust_id              28723
# tran_date            23053
# prod_subcat_code     28723
# prod_cat_code_y      28723
# Qty                  28723
# Rate                 28723
# Tax                  28723
# total_amt            28723
# Store_type           23053
# _merge               28723
# dtype: int64
